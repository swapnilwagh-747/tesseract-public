# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("datasets/HDFCBANK.csv")
df
# Out:
#             Date    Symbol Series  Prev Close     Open     High      Low  \
# 0     2000-01-03  HDFCBANK     EQ      157.40   166.00   170.00   166.00
# 1     2000-01-04  HDFCBANK     EQ      170.00   182.00   183.45   171.00
# 2     2000-01-05  HDFCBANK     EQ      173.80   170.00   173.90   165.00
# 3     2000-01-06  HDFCBANK     EQ      166.95   168.00   170.00   165.30
# 4     2000-01-07  HDFCBANK     EQ      168.30   162.15   171.00   162.15
# ...          ...       ...    ...         ...      ...      ...      ...
# 5282  2021-03-24  HDFCBANK     EQ     1500.15  1490.90  1506.45  1471.00
# 5283  2021-03-25  HDFCBANK     EQ     1478.80  1490.20  1495.55  1450.25
# 5284  2021-03-26  HDFCBANK     EQ     1463.35  1494.00  1499.00  1474.00
# 5285  2021-03-30  HDFCBANK     EQ     1491.30  1506.65  1562.55  1501.55
# 5286  2021-03-31  HDFCBANK     EQ     1553.70  1548.00  1548.00  1488.00
#
#          Last    Close     VWAP    Volume      Turnover    Trades  \
# ...

# %%
df['Close'] = df['Close'].round()

# %%
df['Close']
# Out:
# 0        170.0
# 1        174.0
# 2        167.0
# 3        168.0
# 4        168.0
#          ...
# 5282    1479.0
# 5283    1463.0
# 5284    1491.0
# 5285    1554.0
# 5286    1494.0
# Name: Close, Length: 5287, dtype: float64

# %%
plt.plot(df['Close'])

# %%
df['Close'].max()
# Out:
# 1696.0

# %%
df['Close']1696

# %%
df['Close']
# Out:
# 0         17.0
# 1         17.0
# 2         17.0
# 3         17.0
# 4         17.0
#          ...
# 5773    1654.0
# 5774    1654.0
# 5775    1651.0
# 5776    1657.0
# 5777    1658.0
# Name: Close, Length: 5778, dtype: float64

# %%
df.index[df.Close == 1696]
# Out:
# Int64Index([5764], dtype='int64')

# %%
from sklearn.preprocessing import Normalizer
