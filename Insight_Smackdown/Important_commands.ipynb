# %% [markdown]
# ### To save plotly graph

# %%
# To save plotly graph as html
pio.write_html(graph_name, file='graph_name.html', auto_open=True)

# %%
"import plotly.graph_objects as go
import plotly.io as pio
fig = go.Figure(data=go.Bar(y=[2, 3, 1]))
# save as html
pio.write_html(fig, file='bar.html', auto_open=True)
# save as png
pio.write_image(fig, file='bar.png')
# save as svg
pio.write_image(fig, file='bar.svg')
# save as pdf
pio.write_image(fig, file='bar.pdf')


#  you could get full completion or alternatives in Copilot https://copilot.github.com/"
